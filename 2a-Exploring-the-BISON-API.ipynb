# %% [markdown]
# ## Using the BISON API
# The USGS provides an API for accessing species observation data. https://bison.usgs.gov/doc/api.jsp
#
# This API is much better documented than the NWIS API, and we'll use it to dig a bit deeper into how the `requests` package can faciliate data access via APIs.

# %% [markdown]
# * We'll begin by replicating the example API call they show on their web page:<br>
# [https://bison.usgs.gov/api/search.json?species=Bison bison&type=scientific_name&start=0&count=1](
# https://bison.usgs.gov/api/search.json?species=Bison%20bison&type=scientific_name&start=0&count=1)

# %%
#First, import the wonderful requests module
import requests

# %% [markdown]
# * Now, we'll deconstruct the example URL into the service URL and parameters, saving the paramters as a dictionary. Note we are just providing a few of the parameters available through the [API](https://bison.usgs.gov/doc/api.jsp#opensearch). We could add more search criteria if we wanted, but for now we just want to grab the first 500 Bison records.

# %%
# Construct the service URL as two components: the service URL and the request parameters
url = 'http://bison.usgs.gov/api/search.json'
params = {'species':'Bison bison',
          'type':'scientific_name',
          'start':'0',
          'count':'500'
         }

# %% [markdown]
# * With the components set as variables, we use the `requests.get()` function to send our request off to the server at the address provided, storing the servers response as a variable called `response`.

# %%
#Send the request to the server and store the response as a variable
response = requests.get(url,params)

# %% [markdown]
# * This response object contains a number of properties and methods. Let's have a look at the reponse in raw text format.

# %%
#View the reponse in text format
response.text
# Out:
# '{"occurrences":{"legend":{"fossil":359,"observation":927,"centroid":1,"specimen":946,"unknown":6}},"total":2238,"searchTime":986,"offset":0,"data":[{"geo":"Yes","provider":"Conservation of Arctic Flora and Fauna","name":"Bison bison","decimalLongitude":"-117.6500015258789","decimalLatitude":"61.366668701171875","occurrenceID":"68428522","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"Conservation of Arctic Flora and Fauna","name":"Bison bison","decimalLongitude":"-117.6500015258789","decimalLatitude":"61.366668701171875","occurrenceID":"68428523","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"Conservation of Arctic Flora and Fauna","name":"Bison bison","decimalLongitude":"-117.6500015258789","decimalLatitude":"61.366668701171875","occurrenceID":"68428524","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"Conservation of Arctic Flora and Fauna","name":"Bison bison","decimalLongitude":"-117.6500015258789","decimalLatitude":"61.366668701171875","occurrenceID":"68428525","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"Conservation of Arctic Flora and Fauna","name":"Bison bison","decimalLongitude":"-117.6500015258789","decimalLatitude":"61.366668701171875","occurrenceID":"68428526","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"Conservation of Arctic Flora and Fauna","name":"Bison bison","decimalLongitude":"-117.6500015258789","decimalLatitude":"61.366668701171875","occurrenceID":"68428531","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"Conservation of Arctic Flora and Fauna","name":"Bison bison","decimalLongitude":"-117.6500015258789","decimalLatitude":"61.366668701171875","occurrenceID":"68428532","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"Yes","provider":"Conservation of Arctic Flora and Fauna","name":"Bison bison","decimalLongitude":"-117.6500015258789","decimalLatitude":"61.366668701171875","occurrenceID":"68428533","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Observation"},{"geo":"No","provider":"Berkeley Natural History Museums","name":"Bison bison","occurrenceID":"80957864","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Fossil"},{"geo":"No","provider":"Royal Ontario Museum","name":"Bison bison","occurrenceID":"80957874","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Fossil"},{"geo":"No","provider":"National Museum of Natural History, Smithsonian Institution","name":"Bison bison","occurrenceID":"80957877","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Specimen"},{"geo":"No","provider":"Royal Ontario Museum","name":"Bison bison","occurrenceID":"80957879","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Fossil"},{"geo":"No","provider":"Berkeley Natural History Museums","name":"Bison bison","occurrenceID":"80957880","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Fossil"},{"geo":"No","provider":"Western Australian Museum","name":"Bison bison","occurrenceID":"81018515","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Specimen"},{"geo":"No","provider":"Royal Ontario Museum","name":"Bison bison","occurrenceID":"81018516","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Specimen"},{"geo":"No","provider":"Royal Ontario Museum","name":"Bison bison","occurrenceID":"81018517","common_name":"bison, American bison, American Bison, Bisonte americano","basis":"Specimen"},{"geo": ...

# %% [markdown]
# **Yikes**, that's much less readable than the NWIS output!
#
# Well, that's because the response from the BISON server is in **JSON** format. JSON, short for *JavaScript Object Notation*, is a text document that stores information in `key`:`value` pairs, *much like a Python dictionary*. Still, it's a raw text object, but one that we convert into a Python dictionary using Python's json package.

# %%
#Import the module
import json

#Convert the response 
data = json.loads(response.text)
type(data)
# Out:
# dict

# %% [markdown]
# > *Note*: we could also convert this to JSON using the `json` function of the `response` object...<br>The code below has the exact same results as the one above.

# %%
data=response.json()
type(data)
# Out:
# dict

# %% [markdown]
# * Ok, if it's a dictionary, what are it's keys?

# %%
#List the keys in the returned JSON object
data.keys()
# Out:
# dict_keys(['occurrences', 'total', 'searchTime', 'offset', 'data', 'species', 'eezs', 'itemsPerPage', 'counties', 'type', 'georeferenced', 'states'])

# %% [markdown]
# * What are the values linked with the 'data' key?

# %%
#Show the value associated with the `data` key
data['data']
# Out:
# [{'geo': 'Yes',
#   'provider': 'Conservation of Arctic Flora and Fauna',
#   'name': 'Bison bison',
#   'decimalLongitude': '-117.6500015258789',
#   'decimalLatitude': '61.366668701171875',
#   'occurrenceID': '68428522',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'Conservation of Arctic Flora and Fauna',
#   'name': 'Bison bison',
#   'decimalLongitude': '-117.6500015258789',
#   'decimalLatitude': '61.366668701171875',
#   'occurrenceID': '68428523',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'Conservation of Arctic Flora and Fauna',
#   'name': 'Bison bison',
#   'decimalLongitude': '-117.6500015258789',
#   'decimalLatitude': '61.366668701171875',
#   'occurrenceID': '68428524',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'Conservation of Arctic Flora and Fauna',
#   'name': 'Bison bison',
#   'decimalLongitude': '-117.6500015258789',
#   'decimalLatitude': '61.366668701171875',
#   'occurrenceID': '68428525',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'Conservation of Arctic Flora and Fauna',
#   'name': 'Bison bison',
#   'decimalLongitude': '-117.6500015258789',
#   'decimalLatitude': '61.366668701171875',
#   'occurrenceID': '68428526',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'Conservation of Arctic Flora and Fauna',
#   'name': 'Bison bison',
#   'decimalLongitude': '-117.6500015258789',
#   'decimalLatitude': '61.366668701171875',
#   'occurrenceID': '68428531',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'Conservation of Arctic Flora and Fauna',
#   'name': 'Bison bison',
#   'decimalLongitude': '-117.6500015258789',
#   'decimalLatitude': '61.366668701171875',
#   'occurrenceID': '68428532',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'Yes',
#   'provider': 'Conservation of Arctic Flora and Fauna',
#   'name': 'Bison bison',
#   'decimalLongitude': '-117.6500015258789',
#   'decimalLatitude': '61.366668701171875',
#   'occurrenceID': '68428533',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '80957864',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '80957874',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '80957877',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '80957879',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '80957880',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Western Australian Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018515',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018516',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018517',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018518',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018519',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018520',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018522',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018523',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018525',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81018526',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018528',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018530',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018532',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Australian Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81018533',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81018871',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019430',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019447',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019461',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Texas at El Paso Biodiversity Collections',
#   'name': 'Bison bison',
#   'occurrenceID': '81019512',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019513',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019515',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019516',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019517',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019518',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019519',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019520',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019521',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Alaska Museum of the North',
#   'name': 'Bison bison',
#   'occurrenceID': '81019522',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019523',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019524',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019525',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019526',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019527',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019528',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019529',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019530',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019531',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019532',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019533',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019534',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019535',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019536',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019537',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Kansas Biodiversity Institute',
#   'name': 'Bison bison',
#   'occurrenceID': '81019538',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019539',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019540',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Kansas Biodiversity Institute',
#   'name': 'Bison bison',
#   'occurrenceID': '81019541',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '81019542',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019543',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019544',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019545',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019546',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019547',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019548',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019549',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '81019550',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019551',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019552',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019553',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019554',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '81019555',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019556',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '81019557',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019558',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019559',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019560',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019561',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019562',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019563',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019564',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019565',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019566',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019567',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019569',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019570',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019571',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019572',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019574',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019575',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019576',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019577',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019578',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019579',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019580',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019581',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019582',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Museum of Southwestern Biology',
#   'name': 'Bison bison',
#   'occurrenceID': '81019583',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019585',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '81019586',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019587',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '81019588',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019589',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museo Argentino de Ciencias Naturales',
#   'name': 'Bison bison',
#   'occurrenceID': '81019590',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Arkansas Collections Facility, UAFMC',
#   'name': 'Bison bison',
#   'occurrenceID': '81019591',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '81019592',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019593',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019594',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '81019595',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019597',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019598',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Alberta Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019599',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019600',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019601',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019602',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019603',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019604',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019605',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Alberta Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019606',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019607',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019608',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019609',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019610',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019611',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019612',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019613',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019614',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019615',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019616',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Kansas Biodiversity Institute',
#   'name': 'Bison bison',
#   'occurrenceID': '81019617',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019618',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019619',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '81019620',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019621',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Alberta Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019622',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Alberta Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019623',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019624',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019625',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'James R. Slater Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019626',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019627',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Kansas Biodiversity Institute',
#   'name': 'Bison bison',
#   'occurrenceID': '81019628',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019629',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019630',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019631',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019632',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019633',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019634',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019635',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museo Argentino de Ciencias Naturales',
#   'name': 'Bison bison',
#   'occurrenceID': '81019636',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019637',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Arkansas Collections Facility, UAFMC',
#   'name': 'Bison bison',
#   'occurrenceID': '81019638',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019639',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019640',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019641',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '81019642',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019643',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019644',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019645',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Iowa Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019646',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019647',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019648',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019649',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019650',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019651',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '81019652',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019653',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019654',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019655',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019656',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019657',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Kansas Biodiversity Institute',
#   'name': 'Bison bison',
#   'occurrenceID': '81019658',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019659',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019660',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019661',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Kansas Biodiversity Institute',
#   'name': 'Bison bison',
#   'occurrenceID': '81019662',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019663',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019664',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'California State University, Chico Vertebrate Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019665',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019666',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019667',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Iowa Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019668',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019669',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019670',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019671',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019672',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Alberta Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019673',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019674',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019675',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019676',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019677',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019678',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019679',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'American Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019680',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019681',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019682',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019683',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019684',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019685',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019687',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019688',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019689',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019690',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019691',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019692',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019693',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019694',
# ...
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019925',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019926',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019927',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019928',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019929',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019930',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019931',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019932',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '81019933',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019934',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019935',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019936',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019937',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019938',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '81019939',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019940',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019941',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019942',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019943',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Alberta Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019945',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019946',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019947',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019948',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019949',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019950',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019951',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019952',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'James R. Slater Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019953',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019954',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019955',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019956',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Arkansas Collections Facility, UAFMC',
#   'name': 'Bison bison',
#   'occurrenceID': '81019957',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '81019958',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019959',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019960',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Kansas Biodiversity Institute',
#   'name': 'Bison bison',
#   'occurrenceID': '81019961',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019962',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019963',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019964',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019965',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019966',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Kansas Biodiversity Institute',
#   'name': 'Bison bison',
#   'occurrenceID': '81019967',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019968',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019969',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019970',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019971',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Bison bison',
#   'occurrenceID': '81019972',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019973',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019974',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Cornell Lab of Ornithology',
#   'name': 'Bison bison',
#   'occurrenceID': '81019975',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Observation'},
#  {'geo': 'No',
#   'provider': 'University of Alberta Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019976',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Denver Museum of Nature & Science',
#   'name': 'Bison bison',
#   'occurrenceID': '81019977',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Iowa Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019978',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019979',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019980',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019981',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019982',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019983',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019984',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Natural and Cultural History - University of Oregon',
#   'name': 'Bison bison',
#   'occurrenceID': '81019985',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019986',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019987',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Royal Ontario Museum',
#   'name': 'Bison bison',
#   'occurrenceID': '81019988',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019989',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019990',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019991',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'University of Colorado Museum of Natural History',
#   'name': 'Bison bison',
#   'occurrenceID': '81019992',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Berkeley Natural History Museums',
#   'name': 'Bison bison',
#   'occurrenceID': '81019993',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Bison bison',
#   'occurrenceID': '81019994',
#   'common_name': 'bison, American bison, American Bison, Bisonte americano',
#   'basis': 'Specimen'}]

# %% [markdown]
# * Oh, it's a list of occurrences! Let's examine the first one...

# %%
#Display the first "data" value
data['data'][0]
# Out:
# {'geo': 'Yes',
#  'provider': 'Conservation of Arctic Flora and Fauna',
#  'name': 'Bison bison',
#  'decimalLongitude': '-117.6500015258789',
#  'decimalLatitude': '61.366668701171875',
#  'occurrenceID': '68428522',
#  'common_name': 'bison, American bison, American Bison, Bisonte americano',
#  'basis': 'Observation'}

# %% [markdown]
# * We see it's a dictionary too! Let's list the `decimalLatitude` item value...

# %%
#We can get the latitude of the record from it's `decimalLatitude` key
data['data'][0]['decimalLatitude']
# Out:
# '61.366668701171875'

# %% [markdown]
# ► **So** we see the Bison observations are stored as list of dictionaries which are accessed within the `data` key in the results dictionary generated from the JSON response to our API request. (Phew!)
#
# * With a bit more code we can loop through all the data records and print out the lat and long coordinates...

# %%
#Loop thorough each observation and print the lat and long values
for observation in data['data']:
    print (observation['decimalLatitude'],observation['decimalLongitude'])
# Out:
# 61.366668701171875 -117.6500015258789
# 61.366668701171875 -117.6500015258789
# 61.366668701171875 -117.6500015258789
# 61.366668701171875 -117.6500015258789
# 61.366668701171875 -117.6500015258789
# 61.366668701171875 -117.6500015258789
# 61.366668701171875 -117.6500015258789
# 61.366668701171875 -117.6500015258789
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-0eea537f50b5> in <module>()
#       1 #Loop thorough each observation and print the lat and long values
#       2 for observation in data['data']:
# ----> 3     print (observation['decimalLatitude'],observation['decimalLongitude'])
#
# KeyError: 'decimalLatitude'

# %% [markdown]
# ► *If the above throws an error, can you debug it? HINT: the `geo` tag indicates whether coordinate info exist for the record...*

# %% [markdown]
# ### [Another] Preview of 'Pandas' - that clever Python package with many uses!
# Pandas can create a "data frame" from dictionary values. We'll talk about this soon, but can be quite useful!

# %%
import pandas as pd
df = pd.DataFrame(data['data'])
df.head()
# Out:
#          basis                                        common_name  \
# 0  Observation  bison, American bison, American Bison, Bisonte...
# 1  Observation  bison, American bison, American Bison, Bisonte...
# 2  Observation  bison, American bison, American Bison, Bisonte...
# 3  Observation  bison, American bison, American Bison, Bisonte...
# 4  Observation  bison, American bison, American Bison, Bisonte...
#
#       decimalLatitude    decimalLongitude  geo         name occurrenceID  \
# 0  61.366668701171875  -117.6500015258789  Yes  Bison bison     68428522
# 1  61.366668701171875  -117.6500015258789  Yes  Bison bison     68428523
# 2  61.366668701171875  -117.6500015258789  Yes  Bison bison     68428524
# 3  61.366668701171875  -117.6500015258789  Yes  Bison bison     68428525
# 4  61.366668701171875  -117.6500015258789  Yes  Bison bison     68428526
#
#                                  provider
# 0  Conservation of Arctic Flora and Fauna
# 1  Conservation of Arctic Flora and Fauna
# 2  Conservation of Arctic Flora and Fauna
# 3  Conservation of Arctic Flora and Fauna
# 4  Conservation of Arctic Flora and Fauna

# %% [markdown]
# And Pandas allows us to do some nifty analyses, including subsetting records for a specific provider.
# * First we'll get a list of unique providers found in the data

# %%
#Generate a list of providers
df.provider.unique()
# Out:
# array(['Conservation of Arctic Flora and Fauna',
#        'Berkeley Natural History Museums', 'Royal Ontario Museum',
#        'National Museum of Natural History, Smithsonian Institution',
#        'Western Australian Museum', 'Australian Museum',
#        'University of Texas at El Paso Biodiversity Collections',
#        'University of Alaska Museum of the North',
#        'University of Colorado Museum of Natural History',
#        'Denver Museum of Nature & Science',
#        'University of Kansas Biodiversity Institute',
#        'Museum of Comparative Zoology, Harvard University',
#        'Cornell Lab of Ornithology',
#        'Museum of Natural and Cultural History - University of Oregon',
#        'Museum of Southwestern Biology',
#        'Museo Argentino de Ciencias Naturales',
#        'University of Arkansas Collections Facility, UAFMC',
#        'University of Alberta Museums',
#        'James R. Slater Museum of Natural History',
#        'University of Iowa Museum of Natural History',
#        'California State University, Chico Vertebrate Museum',
#        'American Museum of Natural History',
#        'National Museum of Nature and Science, Japan',
#        'California Academy of Sciences', 'Yale University Peabody Museum',
#        'Natural History Museum', 'Field Museum',
#        'University of British Columbia'], dtype=object)

# %% [markdown]
# * Now, we'll subset the rows that include that provider...

# %%
df.query("provider == 'Denver Museum of Nature & Science'")
# Out:
#         basis                                        common_name  \
# 46   Specimen  bison, American bison, American Bison, Bisonte...
# 47   Specimen  bison, American bison, American Bison, Bisonte...
# 52   Specimen  bison, American bison, American Bison, Bisonte...
# 54   Specimen  bison, American bison, American Bison, Bisonte...
# 58   Specimen  bison, American bison, American Bison, Bisonte...
# 61   Specimen  bison, American bison, American Bison, Bisonte...
# 62   Specimen  bison, American bison, American Bison, Bisonte...
# 65   Specimen  bison, American bison, American Bison, Bisonte...
# 66   Specimen  bison, American bison, American Bison, Bisonte...
# 78   Specimen  bison, American bison, American Bison, Bisonte...
# 90   Specimen  bison, American bison, American Bison, Bisonte...
# 117  Specimen  bison, American bison, American Bison, Bisonte...
# 121  Specimen  bison, American bison, American Bison, Bisonte...
# 145  Specimen  bison, American bison, American Bison, Bisonte...
# 153  Specimen  bison, American bison, American Bison, Bisonte...
# 158  Specimen  bison, American bison, American Bison, Bisonte...
# 159  Specimen  bison, American bison, American Bison, Bisonte...
# 161  Specimen  bison, American bison, American Bison, Bisonte...
# 163  Specimen  bison, American bison, American Bison, Bisonte...
# 164  Specimen  bison, American bison, American Bison, Bisonte...
# 168  Specimen  bison, American bison, American Bison, Bisonte...
# 190  Specimen  bison, American bison, American Bison, Bisonte...
# 197  Specimen  bison, American bison, American Bison, Bisonte...
# 223  Specimen  bison, American bison, American Bison, Bisonte...
# 229  Specimen  bison, American bison, American Bison, Bisonte...
# 247  Specimen  bison, American bison, American Bison, Bisonte...
# 258  Specimen  bison, American bison, American Bison, Bisonte...
# 269  Specimen  bison, American bison, American Bison, Bisonte...
# 308  Specimen  bison, American bison, American Bison, Bisonte...
# 310  Specimen  bison, American bison, American Bison, Bisonte...
# 377  Specimen  bison, American bison, American Bison, Bisonte...
# 400  Specimen  bison, American bison, American Bison, Bisonte...
# 419  Specimen  bison, American bison, American Bison, Bisonte...
# 429  Specimen  bison, American bison, American Bison, Bisonte...
# 460  Specimen  bison, American bison, American Bison, Bisonte...
# 464  Specimen  bison, American bison, American Bison, Bisonte...
# 465  Specimen  bison, American bison, American Bison, Bisonte...
# 468  Specimen  bison, American bison, American Bison, Bisonte...
# 470  Specimen  bison, American bison, American Bison, Bisonte...
# 474  Specimen  bison, American bison, American Bison, Bisonte...
# 475  Specimen  bison, American bison, American Bison, Bisonte...
# 482  Specimen  bison, American bison, American Bison, Bisonte...
#
#     decimalLatitude decimalLongitude geo         name occurrenceID  \
# 46              NaN              NaN  No  Bison bison     81019528
# 47              NaN              NaN  No  Bison bison     81019529
# 52              NaN              NaN  No  Bison bison     81019534
# 54              NaN              NaN  No  Bison bison     81019536
# 58              NaN              NaN  No  Bison bison     81019540
# 61              NaN              NaN  No  Bison bison     81019543
# 62              NaN              NaN  No  Bison bison     81019544
# 65              NaN              NaN  No  Bison bison     81019547
# 66              NaN              NaN  No  Bison bison     81019548
# 78              NaN              NaN  No  Bison bison     81019560
# 90              NaN              NaN  No  Bison bison     81019574
# 117             NaN              NaN  No  Bison bison     81019603
# 121             NaN              NaN  No  Bison bison     81019607
# 145             NaN              NaN  No  Bison bison     81019631
# 153             NaN              NaN  No  Bison bison     81019639
# 158             NaN              NaN  No  Bison bison     81019644
# 159             NaN              NaN  No  Bison bison     81019645
# 161             NaN              NaN  No  Bison bison     81019647
# 163             NaN              NaN  No  Bison bison     81019649
# 164             NaN              NaN  No  Bison bison     81019650
# 168             NaN              NaN  No  Bison bison     81019654
# 190             NaN              NaN  No  Bison bison     81019676
# 197             NaN              NaN  No  Bison bison     81019683
# 223             NaN              NaN  No  Bison bison     81019710
# 229             NaN              NaN  No  Bison bison     81019717
# 247             NaN              NaN  No  Bison bison     81019735
# 258             NaN              NaN  No  Bison bison     81019746
# 269             NaN              NaN  No  Bison bison     81019757
# 308             NaN              NaN  No  Bison bison     81019798
# 310             NaN              NaN  No  Bison bison     81019800
# 377             NaN              NaN  No  Bison bison     81019869
# 400             NaN              NaN  No  Bison bison     81019893
# 419             NaN              NaN  No  Bison bison     81019912
# 429             NaN              NaN  No  Bison bison     81019923
# 460             NaN              NaN  No  Bison bison     81019955
# 464             NaN              NaN  No  Bison bison     81019959
# 465             NaN              NaN  No  Bison bison     81019960
# 468             NaN              NaN  No  Bison bison     81019963
# 470             NaN              NaN  No  Bison bison     81019965
# 474             NaN              NaN  No  Bison bison     81019969
# 475             NaN              NaN  No  Bison bison     81019970
# 482             NaN              NaN  No  Bison bison     81019977
#
#                               provider
# 46   Denver Museum of Nature & Science
# 47   Denver Museum of Nature & Science
# 52   Denver Museum of Nature & Science
# 54   Denver Museum of Nature & Science
# 58   Denver Museum of Nature & Science
# 61   Denver Museum of Nature & Science
# 62   Denver Museum of Nature & Science
# 65   Denver Museum of Nature & Science
# 66   Denver Museum of Nature & Science
# 78   Denver Museum of Nature & Science
# 90   Denver Museum of Nature & Science
# 117  Denver Museum of Nature & Science
# 121  Denver Museum of Nature & Science
# 145  Denver Museum of Nature & Science
# 153  Denver Museum of Nature & Science
# 158  Denver Museum of Nature & Science
# 159  Denver Museum of Nature & Science
# 161  Denver Museum of Nature & Science
# 163  Denver Museum of Nature & Science
# 164  Denver Museum of Nature & Science
# 168  Denver Museum of Nature & Science
# 190  Denver Museum of Nature & Science
# 197  Denver Museum of Nature & Science
# 223  Denver Museum of Nature & Science
# 229  Denver Museum of Nature & Science
# 247  Denver Museum of Nature & Science
# 258  Denver Museum of Nature & Science
# 269  Denver Museum of Nature & Science
# 308  Denver Museum of Nature & Science
# 310  Denver Museum of Nature & Science
# 377  Denver Museum of Nature & Science
# 400  Denver Museum of Nature & Science
# 419  Denver Museum of Nature & Science
# 429  Denver Museum of Nature & Science
# 460  Denver Museum of Nature & Science
# 464  Denver Museum of Nature & Science
# 465  Denver Museum of Nature & Science
# 468  Denver Museum of Nature & Science
# 470  Denver Museum of Nature & Science
# 474  Denver Museum of Nature & Science
# 475  Denver Museum of Nature & Science
# 482  Denver Museum of Nature & Science

# %% [markdown]
# ## Exercise:
# * Extract the first 500 red wolf (*"Canis rufus"*) records from the BISON API.
# * Can you create a table listing the records collected by the `University of Kansas Biodiversity Institute`?
# * *Challenge*: Can you create a table listing all the records collected in North Carolina?

# %%
# Extract the first 1000 red wolf ("Canis rufus") records from the BISON API. 

# Construct the service URL as two components: the service URL and the request parameters
url = 'http://bison.usgs.gov/api/search.json'
params = {'species':'Canis rufus',
          'type':'scientific_name',
          'start':'0',
          'count':'1000'
         }

# %%
#Send the request to the server and store the response as a variable
response = requests.get(url,params)

# %%
#Import the module
import json

#Convert the response 
data = json.loads(response.text)
type(data)
# Out:
# dict

# %%
#List the keys in the returned JSON object
data.keys()
# Out:
# dict_keys(['occurrences', 'total', 'searchTime', 'offset', 'data', 'species', 'eezs', 'itemsPerPage', 'counties', 'type', 'georeferenced', 'states'])

# %%
#Show the value associated with the `data` key
data['data']
# Out:
# [{'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82909859',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82910676',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82911142',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82911261',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82912752',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82913087',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82913885',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82915529',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82916507',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82917720',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82918468',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82918565',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82919627',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82926161',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82928929',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82929873',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82930008',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82931398',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82937204',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82938849',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82939827',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82942025',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82943594',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82947724',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82949447',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82949529',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82949810',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82949828',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82950211',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82952135',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82952362',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82956770',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82956939',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82958292',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82959735',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82960216',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82962488',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82962703',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82963664',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82963933',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82965754',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82966015',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82967102',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82967929',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82968456',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82969644',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82973543',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82975796',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82977683',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82978283',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82978772',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82980567',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82980663',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82981310',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82981340',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82981654',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82983043',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82983095',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82983219',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82983711',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82985030',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82985124',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82986574',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82986988',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82987855',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82988155',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82988306',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82990162',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82990723',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82991752',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82991865',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82992078',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82992379',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82992919',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82993142',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82993414',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82994314',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82994336',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82995860',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82997201',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82997702',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82999006',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '82999928',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83000242',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83004710',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83006434',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83008534',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83009368',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83012470',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Vertebrate Zoology',
#   'name': 'Canis rufus',
#   'occurrenceID': '83014170',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Carnegie Museums',
#   'name': 'Canis rufus',
#   'occurrenceID': '82592692',
#   'common_name': '',
#   'basis': 'Fossil'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83046117',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83046613',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83050413',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83052745',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83054238',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83054554',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Canis rufus',
#   'occurrenceID': '83055161',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Canis rufus',
#   'occurrenceID': '83055365',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83055773',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83061108',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83061830',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Canis rufus',
#   'occurrenceID': '83062511',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Canis rufus',
#   'occurrenceID': '83062752',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83062927',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83063333',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83066294',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83066341',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83071844',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83071888',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83071991',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83072077',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'Museum of Comparative Zoology, Harvard University',
#   'name': 'Canis rufus',
#   'occurrenceID': '83072337',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83073255',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83073329',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83099700',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83100330',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83100838',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83100861',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83101144',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83101198',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83101320',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83101819',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83102290',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83102519',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83102809',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83103010',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83104411',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83104418',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83104586',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83105597',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83106597',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83106660',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83108780',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83110576',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83111230',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83112116',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83112600',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83112707',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83112709',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83113999',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83114075',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83114531',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83115234',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83115619',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83115916',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83117392',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83118736',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83118778',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83119990',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83120149',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83120613',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83121205',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83122348',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83122806',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83122845',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83123041',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83124627',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83124692',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83125585',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83125848',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83126564',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83127073',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83127262',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83127385',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83127410',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83127523',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83128640',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83129956',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83130634',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83130688',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83130789',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83130869',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83131038',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83131188',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83131444',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83131601',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83133166',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83133356',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83133486',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83134748',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83135096',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83135098',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83135535',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83135548',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83136010',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83136925',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83137422',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83138067',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83138808',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83142817',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83143665',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83144080',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83144197',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83144430',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83144676',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83144757',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83145159',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83145526',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83145798',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83146009',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83146570',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83146925',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83147314',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83147714',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83148598',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83149530',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83149927',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83149958',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83150727',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83151244',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83151438',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83151786',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83151857',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83151884',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83152569',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83152653',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83152893',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83154138',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83154434',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83154769',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83155132',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83155158',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83155239',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83156995',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83157354',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83157528',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83157878',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83158148',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83159008',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83159358',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83159645',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83160459',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83160921',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83161342',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83161472',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83161541',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83161717',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83162427',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83162842',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83163196',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83163279',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83163409',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83163661',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83163749',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83163821',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83164363',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83164588',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83165275',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
#   'occurrenceID': '83165778',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'No',
#   'provider': 'National Museum of Natural History, Smithsonian Institution',
#   'name': 'Canis rufus',
# ...
#   'common_name': '',
#   'basis': 'Fossil'},
#  {'geo': 'Yes',
#   'provider': 'American Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-85.79517364501953',
#   'decimalLatitude': '40.84371566772461',
#   'occurrenceID': '229348464',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-93.01199340820312',
#   'decimalLatitude': '29.8032169342041',
#   'occurrenceID': '198857019',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'James R. Slater Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-93.21659851074219',
#   'decimalLatitude': '29.866714477539062',
#   'occurrenceID': '198141997',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Museum of Vertebrate Zoology',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.53118133544922',
#   'decimalLatitude': '36.835330963134766',
#   'occurrenceID': '203246179',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.52996063232422',
#   'decimalLatitude': '31.3211727142334',
#   'occurrenceID': '203249471',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.52996063232422',
#   'decimalLatitude': '31.3211727142334',
#   'occurrenceID': '203249484',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.52996063232422',
#   'decimalLatitude': '31.3211727142334',
#   'occurrenceID': '203249488',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'American Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.16798400878906',
#   'decimalLatitude': '40.405792236328125',
#   'occurrenceID': '204098586',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'American Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.16798400878906',
#   'decimalLatitude': '40.405792236328125',
#   'occurrenceID': '204098601',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-92.83198547363281',
#   'decimalLatitude': '29.789216995239258',
#   'occurrenceID': '199289482',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-92.36398315429688',
#   'decimalLatitude': '31.655160903930664',
#   'occurrenceID': '200760398',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Chicago Academy of Sciences',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.34506225585938',
#   'decimalLatitude': '32.27109909057617',
#   'occurrenceID': '203624733',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.18695068359375',
#   'decimalLatitude': '32.40814208984375',
#   'occurrenceID': '204017880',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.18695068359375',
#   'decimalLatitude': '32.40814208984375',
#   'occurrenceID': '204017886',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-93.11099243164062',
#   'decimalLatitude': '29.815216064453125',
#   'occurrenceID': '198523470',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-93.11099243164062',
#   'decimalLatitude': '29.815216064453125',
#   'occurrenceID': '198523473',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Museum of Vertebrate Zoology',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-92.42649841308594',
#   'decimalLatitude': '36.67953109741211',
#   'occurrenceID': '200543019',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-92.45297241210938',
#   'decimalLatitude': '29.646223068237305',
#   'occurrenceID': '200312666',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Museum of Texas Tech University (TTU)',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-89.87626647949219',
#   'decimalLatitude': '30.9661808013916',
#   'occurrenceID': '208932870',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-90.85693359375',
#   'decimalLatitude': '29.57023048400879',
#   'occurrenceID': '204912860',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Louisiana State University Museum of Natural Science',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-90.90694427490234',
#   'decimalLatitude': '32.245147705078125',
#   'occurrenceID': '204831433',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'University of Washington Burke Museum',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-90.6276626586914',
#   'decimalLatitude': '38.50320053100586',
#   'occurrenceID': '205600146',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'James R. Slater Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-88.68768310546875',
#   'decimalLatitude': '30.24021339416504',
#   'occurrenceID': '213181177',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'American Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-89.0833740234375',
#   'decimalLatitude': '30.416536331176758',
#   'occurrenceID': '211973989',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'Florida Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-80.62999725341797',
#   'decimalLatitude': '28.079999923706055',
#   'occurrenceID': '268270344',
#   'common_name': '',
#   'basis': 'Fossil'},
#  {'geo': 'Yes',
#   'provider': 'Florida Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-80.4000015258789',
#   'decimalLatitude': '27.649999618530273',
#   'occurrenceID': '270070531',
#   'common_name': '',
#   'basis': 'Fossil'},
#  {'geo': 'Yes',
#   'provider': 'Florida Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-80.4000015258789',
#   'decimalLatitude': '27.649999618530273',
#   'occurrenceID': '270070541',
#   'common_name': '',
#   'basis': 'Fossil'},
#  {'geo': 'Yes',
#   'provider': 'Marine Science Institute, UCSB',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-75.30000305175781',
#   'decimalLatitude': '40.20000076293945',
#   'occurrenceID': '312977885',
#   'common_name': '',
#   'basis': 'Fossil'},
#  {'geo': 'Yes',
#   'provider': 'James R. Slater Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-75.91395568847656',
#   'decimalLatitude': '35.83486557006836',
#   'occurrenceID': '306819508',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'James R. Slater Museum of Natural History',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-75.91395568847656',
#   'decimalLatitude': '35.83486557006836',
#   'occurrenceID': '306819509',
#   'common_name': '',
#   'basis': 'Specimen'},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-77.0825424194336',
#   'decimalLatitude': '35.11817932128906',
#   'occurrenceID': '2108627',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-93.08610534667969',
#   'decimalLatitude': '31.734981536865234',
#   'occurrenceID': '2108652',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-90.84419250488281',
#   'decimalLatitude': '29.33326530456543',
#   'occurrenceID': '2108686',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-93.35801696777344',
#   'decimalLatitude': '30.22955894470215',
#   'occurrenceID': '2108747',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-93.16551971435547',
#   'decimalLatitude': '29.871912002563477',
#   'occurrenceID': '2108748',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-93.16551971435547',
#   'decimalLatitude': '29.871912002563477',
#   'occurrenceID': '2108749',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-93.16551971435547',
#   'decimalLatitude': '29.871912002563477',
#   'occurrenceID': '2108750',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.23413848876953',
#   'decimalLatitude': '32.73017120361328',
#   'occurrenceID': '2108751',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-92.56171417236328',
#   'decimalLatitude': '31.597787857055664',
#   'occurrenceID': '2108752',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-92.56171417236328',
#   'decimalLatitude': '31.597787857055664',
#   'occurrenceID': '2108753',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-92.1615982055664',
#   'decimalLatitude': '31.680082321166992',
#   'occurrenceID': '2108754',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-90.39485168457031',
#   'decimalLatitude': '29.491992950439453',
#   'occurrenceID': '2108755',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.24073028564453',
#   'decimalLatitude': '32.36582565307617',
#   'occurrenceID': '2108756',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-91.24073028564453',
#   'decimalLatitude': '32.36582565307617',
#   'occurrenceID': '2108757',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-92.29009246826172',
#   'decimalLatitude': '29.7868709564209',
#   'occurrenceID': '2108758',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-92.64126586914062',
#   'decimalLatitude': '31.941186904907227',
#   'occurrenceID': '2108759',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-92.64126586914062',
#   'decimalLatitude': '31.941186904907227',
#   'occurrenceID': '2108760',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.8420181274414',
#   'decimalLatitude': '35.4823112487793',
#   'occurrenceID': '2108762',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.1536865234375',
#   'decimalLatitude': '35.40815734863281',
#   'occurrenceID': '2108769',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.1536865234375',
#   'decimalLatitude': '35.40815734863281',
#   'occurrenceID': '2108801',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.96236419677734',
#   'decimalLatitude': '36.06132888793945',
#   'occurrenceID': '2108807',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.8420181274414',
#   'decimalLatitude': '35.4823112487793',
#   'occurrenceID': '2108913',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.8420181274414',
#   'decimalLatitude': '35.4823112487793',
#   'occurrenceID': '2108973',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-75.76753997802734',
#   'decimalLatitude': '35.60626983642578',
#   'occurrenceID': '2108986',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-75.76753997802734',
#   'decimalLatitude': '35.60626983642578',
#   'occurrenceID': '2108987',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.1536865234375',
#   'decimalLatitude': '35.40815734863281',
#   'occurrenceID': '2109000',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.1536865234375',
#   'decimalLatitude': '35.40815734863281',
#   'occurrenceID': '2109001',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.1536865234375',
#   'decimalLatitude': '35.40815734863281',
#   'occurrenceID': '2109002',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.16534423828125',
#   'decimalLatitude': '35.870418548583984',
#   'occurrenceID': '2109005',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-77.11286926269531',
#   'decimalLatitude': '35.84105682373047',
#   'occurrenceID': '2109010',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-77.11286926269531',
#   'decimalLatitude': '35.84105682373047',
#   'occurrenceID': '2109011',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.66506958007812',
#   'decimalLatitude': '35.1474609375',
#   'occurrenceID': '2109015',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-77.37240600585938',
#   'decimalLatitude': '35.591064453125',
#   'occurrenceID': '2109016',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.16534423828125',
#   'decimalLatitude': '35.870418548583984',
#   'occurrenceID': '2109020',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.16534423828125',
#   'decimalLatitude': '35.870418548583984',
#   'occurrenceID': '2109021',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.57233428955078',
#   'decimalLatitude': '35.84458923339844',
#   'occurrenceID': '2109022',
#   'common_name': '',
#   'basis': None},
#  {'geo': 'Yes',
#   'provider': 'BISON',
#   'name': 'Canis rufus',
#   'decimalLongitude': '-76.57233428955078',
#   'decimalLatitude': '35.84458923339844',
#   'occurrenceID': '2109023',
#   'common_name': '',
#   'basis': None}]

# %%
import pandas as pd
df = pd.DataFrame(data['data'])
df.head()
# Out:
#       basis common_name decimalLatitude decimalLongitude geo         name  \
# 0  Specimen                         NaN              NaN  No  Canis rufus
# 1  Specimen                         NaN              NaN  No  Canis rufus
# 2  Specimen                         NaN              NaN  No  Canis rufus
# 3  Specimen                         NaN              NaN  No  Canis rufus
# 4  Specimen                         NaN              NaN  No  Canis rufus
#
#   occurrenceID                                           provider
# 0     82909859  National Museum of Natural History, Smithsonia...
# 1     82910676  National Museum of Natural History, Smithsonia...
# 2     82911142  National Museum of Natural History, Smithsonia...
# 3     82911261  National Museum of Natural History, Smithsonia...
# 4     82912752  National Museum of Natural History, Smithsonia...

# %%
# Create a table listing the records collected by the University of Kansas Biodiversity Institute
df.query("provider == 'University of Kansas Biodiversity Institute'")
# Out:
#         basis common_name     decimalLatitude    decimalLongitude  geo  \
# 526  Specimen              29.729999542236328  -96.31999969482422  Yes
# 546  Specimen              29.579999923706055  -96.51000213623047  Yes
# 548  Specimen              29.530000686645508  -96.56999969482422  Yes
# 549  Specimen              29.530000686645508  -96.56999969482422  Yes
# 550  Specimen              29.530000686645508  -96.56999969482422  Yes
# 551  Specimen              27.809999465942383  -97.06999969482422  Yes
# 553  Specimen               29.59000015258789  -96.63999938964844  Yes
# 557  Specimen                29.6299991607666  -96.62000274658203  Yes
# 591  Specimen              29.239999771118164  -95.16999816894531  Yes
# 592  Specimen              29.239999771118164  -95.16999816894531  Yes
#
#             name occurrenceID                                     provider
# 526  Canis rufus    185722766  University of Kansas Biodiversity Institute
# 546  Canis rufus    185220474  University of Kansas Biodiversity Institute
# 548  Canis rufus    185005282  University of Kansas Biodiversity Institute
# 549  Canis rufus    185005284  University of Kansas Biodiversity Institute
# 550  Canis rufus    185005286  University of Kansas Biodiversity Institute
# 551  Canis rufus    182113165  University of Kansas Biodiversity Institute
# 553  Canis rufus    184574899  University of Kansas Biodiversity Institute
# 557  Canis rufus    184686921  University of Kansas Biodiversity Institute
# 591  Canis rufus    190415693  University of Kansas Biodiversity Institute
# 592  Canis rufus    190415694  University of Kansas Biodiversity Institute

# %%
# Challenge: Create a table listing all the records collected in North Carolina

url = 'http://bison.usgs.gov/api/search.json'
params = {'states':'North Carolina'
         }

#Send the request to the server and store the response as a variable
response = requests.get(url,params)

#Convert the response 
data = json.loads(response.text)

df = pd.DataFrame(data['data'])

print(df)
# Out:
#           basis                                        common_name  \
# 0   Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 1   Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 2   Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 3   Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 4   Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 5   Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 6   Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 7   Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 8   Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 9   Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 10  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 11  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 12  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 13  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 14  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 15  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 16  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 17  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 18  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 19  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 20  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 21  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 22  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 23  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
# 24  Observation  Myrtle Warbler, Yellow-rumped Warbler, Chipe c...
#
#        decimalLatitude     decimalLongitude  geo                         name  \
# 0    37.91667175292969   -75.41667175292969  Yes  Setophaga coronata coronata
# 1    37.91667175292969   -75.41667175292969  Yes  Setophaga coronata coronata
# 2    37.91667175292969   -75.41667175292969  Yes  Setophaga coronata coronata
# 3    37.91667175292969   -75.41667175292969  Yes  Setophaga coronata coronata
# 4                41.75   -70.08332824707031  Yes  Setophaga coronata coronata
# 5                32.75   -79.91667175292969  Yes  Setophaga coronata coronata
# 6                46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 7    37.91667175292969   -75.41667175292969  Yes  Setophaga coronata coronata
# 8                46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 9                46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 10   37.91667175292969   -75.41667175292969  Yes  Setophaga coronata coronata
# 11  31.083330154418945   -81.41667175292969  Yes  Setophaga coronata coronata
# 12               46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 13   36.08332824707031               -86.75  Yes  Setophaga coronata coronata
# 14               46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 15               46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 16               46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 17               46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 18               46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 19   37.91667175292969   -75.41667175292969  Yes  Setophaga coronata coronata
# 20               46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 21               46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 22               46.75   -84.91667175292969  Yes  Setophaga coronata coronata
# 23   37.91667175292969   -75.41667175292969  Yes  Setophaga coronata coronata
# 24               48.75  -115.91670227050781  Yes  Setophaga coronata coronata
#
#    occurrenceID provider
# 0      51677313    BISON
# 1      51677314    BISON
# 2      51677315    BISON
# 3      51677316    BISON
# 4      51677317    BISON
# 5      51677318    BISON
# 6      51677319    BISON
# 7      51677320    BISON
# 8      51677321    BISON
# 9      51677322    BISON
# 10     51677323    BISON
# 11     51677324    BISON
# 12     51677325    BISON
# 13     51677326    BISON
# 14     51677327    BISON
# 15     51677328    BISON
# 16     51677329    BISON
# 17     51677330    BISON
# 18     51677331    BISON
# 19     51677332    BISON
# 20     51677333    BISON
# 21     51677334    BISON
# 22     51677335    BISON
# 23     51677336    BISON
# 24     51677337    BISON
